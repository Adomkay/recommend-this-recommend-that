672265 424998899 359655030 2018626642 3779774678 2826696904 1865316985 3638166237 1277881576 65153928 151472514 197938851 1791529151 70716253 353842996 3535378478 919239268 1648812593 1238514056 3942763300 3205489980 3980824347 1339437560 888523043 1891903963 3287586716 1619158385 154672902 3111580973 2009430909 2097151830 4209604623 2979675991 1643095644 2519505848 3746108802 2366871747 4050073932 1434089257 1204842250 980559492 1157929000 2881599781 2776342728 3837206118 1386632486 3608213073 1950404042 1739315389 2235888339 1391342069 4212758466 270948933 2960023197 3232371079 2796035436 381121189 3566255531 3335944272 3337678571 2261085110 334663224 4262499465 2283311802 2804198080 399587236 2636044243 1790654624 1915370549 2038958674 2849551202 2519473778 2962670796 2407226400 4214582142 3426002487 1416375868 3694059616 122593031 3760297740 3094606087 2015712071 3892746996 1955897490 4068982761 2134596711 3849376652 2761557792 776102237 1915349363 942930809 121098081 2801811904 231 ...

# %%
user_friends_df.to_csv('user_friends1.csv')

# %%
with open('data/events.csv', 'rb') as ed:
    gzip_ed = gzip.GzipFile(fileobj=ed)
    events_df = pd.read_csv(gzip_ed)

# %%
events_df.drop(columns = ['zip'], inplace = True)
events_df.dropna(inplace = True)

# %%
events_df = events_df[['event_id', 'user_id', 'city', 'state', 'country', 'lat', 'lng']]

# %%
events_df.to_csv('events1.csv')

# %%
events_df.head(3)
# Out:
#        event_id     user_id           city   state        country     lat  \
# 40   2587616435  3053278014  Sihanoukville  Kampot       Cambodia  10.633
# 51   1145166049  2509951454      Palo Alto      CA  United States  37.442
# 156  3580637647  1501747205    Los Angeles      CA  United States   3.156
#
#          lng
# 40   103.500
# 51  -122.172
# 156  101.612

# %%
with open('data/event_attendees.csv', 'rb') as ead:
    gzip_ead = gzip.GzipFile(fileobj=ead)
    event_attendees_df = pd.read_csv(gzip_ead)

# %%
event_attendees_df.shape
# Out:
# (24144, 5)

# %%
event_attendees_df.dropna(inplace = True)

# %%
event_attendees_df.to_csv('event_attendees1.csv')

# %%
event_attendees_df.head(3)
# Out:
#         event                                                yes  \
# 0  1159822043  1975964455 252302513 4226086795 3805886383 142...
# 4   855842686  2406118796 3550897984 294255260 1125817077 109...
# 6   488116622  4145960786 2550625355 2577667841 1575121941 28...
#
#                                                maybe  \
# 0  2733420590 517546982 1350834692 532087573 5831...
# 4  2671721559 1761448345 2356975806 2666669465 10...
# 6  1227223575 2789471603 1323321680 3086272918 38...
#
#                                              invited  \
# 0  1723091036 3795873583 4109144917 3560622906 31...
# 4  1518670705 880919237 2326414227 2673818347 332...
# 6  1413359297 2300232602 1412759254 617751520 286...
#
#                                                   no
# 0                              3575574655 1077296663
# 4                                         3500235232
# 6  1498160155 3708150269 823488244 3595018395 173...

# %%
###### Create the nodes relative to Users, each one being identified by its user_id #####
# "MERGE" request : creates a new node if it does not exist already
tx = graph.begin()
statement1 = 'CREATE CONSTRAINT ON (u:User) ASSERT u.user_id IS UNIQUE'
tx.evaluate(statement1)
statement2 = '''USING PERIODIC COMMIT 
MERGE (u:`User`{user_id:{A}, location:{B}}) RETURN u'''
for u, row in user_df.iterrows():
    tx.evaluate(statement2, {"A":row.loc['user_id'], "B": row.loc['location']})
tx.commit()

# %%
###### Create the nodes relative to Events, each one being identified by its event_id #####
# "MERGE" request : creates a new node if it does not exist already
tx = graph.begin()
statement1 = 'CREATE CONSTRAINT ON (e:Event) ASSERT e.user_id IS UNIQUE'
tx.evaluate(statement1)
statement2 = '''USING PERIODIC COMMIT 
MERGE (u:`User`{user_id:{A}, location:{B}}) RETURN u'''
for u, row in user_df.iterrows():
    tx.evaluate(statement2, {"A":row.loc['user_id'], "B": row.loc['location']})
tx.commit()
