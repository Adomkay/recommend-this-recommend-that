# %% [markdown]
# # Event Recommender System

# %% [markdown]
# ## Data Relationships

# %%
from IPython.display import Image, display
display(Image(filename='database_schema.png'))

# %% [markdown]
# ## What are popular topics?
# ### Why? Use PageRank

# %% [markdown]
# ## What are popular Groups?
# ### Why? Use PageRank

# %% [markdown]
# ## What are the popular Venues?
# ### Why? Use PageRank

# %% [markdown]
# ## What events should be recommended to members?
# ### Jaccard Similarity algorithm

# %% [markdown]
# ## What new topics should be recommended to members?
# ### Jaccard Similarity algorithm

# %% [markdown]
# ## What members should be recommended to groups?
# ### Jaccard Similarity algorithm

# %% [markdown]
# ## What new locations should be recommended to groups?
# ### Jaccard Similarity algorithm

# %% [markdown]
# ## What group collaborations can occur?
# ### Use jaccard similarity algorithms to get complementary groups in same city and different city
# ### Use betweenness and closeness centrality algorithms to get members that can make introductions.
# ### Combine betweenness and shortest path to get connections for introductions.

# %% [markdown]
# ### Plot locations of members on map of USA

# %% [markdown]
# ### Plot distribution of topics

# %% [markdown]
# ### Get most Popular Groups by Category (use dropdown widgets)

# %%
import json
